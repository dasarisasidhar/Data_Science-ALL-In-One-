# %%
# directly in pandas with matplotlibimport pandas as pd

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('../Datasets/titanic/train.csv')
test_df = pd.read_csv('../Datasets/titanic/test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.plot.scatter(y = "Age", x = "Fare", c= "Pclass",  colormap = "viridis");

#age vs fare with color Pclass

# %%
# using sns

# %%
import seaborn as sns

# %%
#KDE plot use to plot pdf(prob distribution fun that applies to your data)
